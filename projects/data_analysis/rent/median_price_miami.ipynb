# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.read_csv('D:/Cloud/Nastya/IT/python/median_price.csv') # reading data
df_miami = df.loc[df['City']=='Miami']

### Lines with plt
# df_miami_transp.plot(kind = 'line', figsize=(20,10), rot=90)
# plt.title('The dynamic of average prices of 1 bedroom apartments in Miami')
# plt.show()

### Draw lines using go, like 2 diff, without subplots

# ## dynamic since 2010 to 2016, by years means
# # adding new columns with yearly mean
# for year in list(map(str,range(2010,2017))):
#     df_miami[year] = df_miami.filter(like=year, axis=1).mean(axis=1)
# df_miami_new = df_miami.set_index('RegionName').transpose().reset_index().iloc[-7:] #  transposing columns into rows
# # drawing figure
# fig = go.Figure()
# for region in df_miami['RegionName']:
# 	fig.add_trace(go.Scatter(y=df_miami_new[region], x=df_miami_new['index'], mode='lines+markers', name=region))
# fig.update_layout(title={'text': "The dynamic of average prices of 1 bedroom apartments in Miami by years"})
# fig.show()
# ## dynamic since 2010 to 2016
# df_miami_new2 = df_miami.set_index('RegionName').transpose().reset_index().iloc[5:-7] #  transposing columns into rows
# # draw figure    
# fig = go.Figure()
# for region in df_miami['RegionName']:
# 	fig.add_trace(go.Scatter(y=df_miami_new2[region], x=df_miami_new2['index'], mode='lines+markers', name=region))
# fig.update_layout(title={'text': "The dynamic of average prices of 1 bedroom apartments in Miami"})
# fig.show()
# ## dynamic for 2014
# df_miami_2014 = df_miami.set_index('RegionName').transpose().reset_index().iloc[-40:-28] #  transposing columns into rows
# # draw lines    
# fig = go.Figure()
# for region in df_miami['RegionName']:
# 	fig.add_trace(go.Scatter(y=df_miami_2014[region], x=df_miami_2014['index'], mode='lines+markers', name=region))
# fig.update_layout(title={'text': "The dynamic of average prices of 1 bedroom apartments in Miami during 2014"})
# fig.show()
# ## dynamic for 2015
# df_miami_2015 = df_miami.set_index('RegionName').transpose().reset_index().iloc[-28:-16] #  transposing columns into rows
# # draw lines    
# fig = go.Figure()
# for region in df_miami['RegionName']:
# 	fig.add_trace(go.Scatter(y=df_miami_2015[region], x=df_miami_2015['index'], mode='lines+markers', name=region))
# fig.update_layout(title={'text': "The dynamic of average prices of 1 bedroom apartments in Miami during 2015"})
# fig.show()
# ## dynamic for 2016
# df_miami_2016 = df_miami.set_index('RegionName').transpose().reset_index().iloc[-16:-7] #  transposing columns into rows
# # draw lines    
# fig = go.Figure()
# for region in df_miami['RegionName']:
# 	fig.add_trace(go.Scatter(y=df_miami_2016[region], x=df_miami_2016['index'], mode='lines+markers', name=region))
# fig.update_layout(title={'text': "The dynamic of average prices of 1 bedroom apartments in Miami during 2016"})
# fig.show()
## dynamic since 2014 to 2016
df_miami_2014_16 = df_miami.set_index('RegionName').transpose().reset_index().iloc[-40:-7] #  transposing columns into rows
# draw lines
fig = go.Figure()
for region in df_miami['RegionName']:
	fig.add_trace(go.Scatter(y=df_miami_2014_16[region], x=df_miami_2014_16['index'], mode='lines+markers', name=region))
fig.update_layout(title={'text': "The dynamic of average prices of 1 bedroom apartments in Miami from 2014 to 2016"})
fig.show()

# ### Draw lines with subplots if needed
# fig = make_subplots(rows=2, cols=1, subplot_titles=("The dynamic of average prices of 1 bedroom apartments in Miami by years", "The dynamic of average prices of 1 bedroom apartments in Miami"))
# # adding new columns with yearly mean
# for year in list(map(str,range(2010,2017))):
#     df_miami[year] = df_miami.filter(like=year, axis=1).mean(axis=1)
# df_miami_new = df_miami.set_index('RegionName').transpose().reset_index().iloc[-7:] #  transposing columns into rows
# for region in df_miami['RegionName']:
# 	fig.add_trace(go.Scatter(y=df_miami_new[region], x=df_miami_new['index'], mode='lines+markers', name=region), row = 1, col = 1)
# # draw new lines
# df_miami_new2 = df_miami.set_index('RegionName').transpose().reset_index().iloc[5:-7] #  transposing columns into rows
# for region in df_miami['RegionName']:
# 	fig.add_trace(go.Scatter(y=df_miami_new2[region], x=df_miami_new2['index'], mode='lines+markers', name=region),row = 2, col = 1)
# fig.show()

mean_rent = df_miami_new2.mean()
min_rent = df_miami_new2.min()
max_rent = df_miami_new2.max()
print(mean_rent, min_rent, max_rent)

### Conlusion: the prices in more expensive areas slowly went down since late 2014 till mid 2015. 
### And then slowly went up. More chiper places have sharp ups and downs but eventually go up.
# Out:
# <div>
#
#
#             <div id="096b46b6-95eb-4750-bb47-ecf00aa6a930" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("096b46b6-95eb-4750-bb47-ecf00aa6a930")) {
#                     Plotly.newPlot(
#                         '096b46b6-95eb-4750-bb47-ecf00aa6a930',
# ...
