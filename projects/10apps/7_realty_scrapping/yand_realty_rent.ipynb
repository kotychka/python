# %%
import requests, re
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime as dt

# %%
url = 'https://realty.yandex.ru/sankt-peterburg/snyat/kvartira/studiya/metro-devyatkino/?metroTransport=ON_FOOT&timeToMetro=10&sort=DATE_DESC'
url_to_pages=url+'&page='
site='https://'+url.split('/')[2]

soup=BeautifulSoup(requests.get(url).content,"html.parser")
page_numb=int(int(soup.find("div",{"FormField_name_submit"}).text.split(' ')[1])/20)

# %%
apartm_list=[]
for page in range(0,int(page_numb/4)):
    soup=BeautifulSoup(requests.get(url_to_pages+str(page)).content,"html.parser")
    data=soup.find_all("ol",{"OffersSerp__list"})[0].find_all('li',{'OffersSerpItem'})
    print(page) # to track if there would be an error
    for item in data:
        apartm_dict={}
        link=site+item.find('a',{'OffersSerpItem__link'}, href=True)['href']
        new_soup=BeautifulSoup(requests.get(link).content,"html.parser").find_all('div',{'Offer'})[0]
        build=item.find_all('div',{'OffersSerpItem__building'})[0].text.split(', ')
        print(build) # to track if there would be an error
        
        apartm_dict['title']=item.find('h3',{'OffersSerpItem__title'}).text     
        apartm_dict['zhk']=build[0]
        try:
            apartm_dict['layer']=build[1]
        except:
            if 'этаж' in build[0]:
                apartm_dict['layer']=build[0]
                apartm_dict['zhk']=None
            else:
                apartm_dict['layer']=None
        apartm_dict['address']=item.find('div',{'OffersSerpItem__address'}).text
        try:
            fees=new_soup.find('span',{'OfferDealDescription__info-item'}).text
            if "комисси" in fees: 
                apartm_dict['fees']=fees
            else:
                apartm_dict['fees']=None  
        except:
            apartm_dict['fees']=None
        apartm_dict['location']=item.find('span',{'MetroWithTime__body'}).text[10:-5]
        apartm_dict['price']=item.find('span',{'price'}).text
        try:
            apartm_dict['desc']=item.find('p',{'OffersSerpItem__description'}).text
        except:    
            apartm_dict['desc']=None
        try:
            apartm_dict['full_desc']=new_soup.find('p',{'OfferTextDescription__text'}).text
        except:    
            apartm_dict['full_desc']=None
        try:
            apartm_dict['date']=new_soup.find('div',{'OfferPublishedDate'}).text
        except:
            apartm_dict['date']=item.find('div',{'OffersSerpItem__publish-date'}).text
        try:
            apartm_dict['update_date']=apartm_dict['date'].split('(')[1][10:-1]
        except:
            apartm_dict['update_date']=apartm_dict['date']
        apartm_dict['link']=link
        apartm_list.append(apartm_dict)

df=pd.DataFrame(apartm_list)
df.to_excel("first.xlsx")
# Out:
# 0
# ЖК «Мой город» 11 этаж из 22
# ЖК «Виктория (Мурино)» 16 этаж из 24
# Квартал «Солнечный» 16 этаж из 16
# ЖК «Эланд» 8 этаж из 25
# ЖК «Три кита» 10 этаж из 12
# ЖК «Мой город» 10 этаж из 22
# ЖК «Виктория (Мурино)» 10 этаж из 25
# ЖК «Мой город» 7 этаж из 22
# Квартал «Солнечный» 13 этаж из 16
# ЖК «Мой город» 14 этаж из 21
# ЖК «Мечта» 8 этаж из 17
# Квартал «Солнечный» 5 этаж из 16
# ЖК «Мечта» 5 этаж из 15
# ЖК «Виктория (Мурино)» 15 этаж из 24
# ЖК «Виктория (Мурино)» 22 этаж из 22
# ЖК «Мой город» 15 этаж из 15
# ЖК «Девятый вал» 20 этаж из 22
# ЖК «Виктория (Мурино)» 9 этаж из 22
# ЖК «Мой город» 17 этаж из 22
# ЖК «Мой город» 22 этаж из 24
# 1
# ЖК «Мой город» 15 этаж из 24
# ЖК «Мой город» 13 этаж из 18
# ЖК «Мой город» 9 этаж из 22
# ЖК «Виктория (Мурино)» 14 этаж из 21
# ЖК «Виктория (Мурино)» 15 этаж из 24
# ЖК «Мой город» 8 этаж из 24
# Квартал «Солнечный» 15 этаж из 16
# ЖК «Мечта» 13 этаж из 23
# ЖК «Виктория (Мурино)» 12 этаж из 23
# ЖК «Виктория (Мурино)» 16 этаж из 21
# ЖК «Виктория (Мурино)» 16 этаж из 21
# ЖК «Виктория (Мурино)» 16 этаж из 24
# ЖК «Мой город» 13 этаж из 19
# ЖК «Охтинская дуга» 5 этаж из 16
# ЖК «Эланд» 17 этаж из 25
# ЖК «Мечта» 13 этаж из 14
# ЖК «Мой город» 10 этаж из 17
# ЖК «Мой город» 17 этаж из 23
# ЖК «Виктория (Мурино)» 23 этаж из 24
# Квартал «Солнечный» 11 этаж из 18
# 2
# ЖК «Девятый вал» 14 этаж из 26
# ЖК «Мой город» 7 этаж из 24
# ЖК «Охтинская дуга» 7 этаж из 25
# ЖК «Мой город» 11 этаж из 22
# ЖК «Мой город» 23 этаж из 26
# ЖК «Мой город» 7 этаж из 24
# ЖК «Мой город» 13 этаж из 21
# ЖК «Виктория (Мурино)» 2 этаж из 22
# ЖК «Виктория (Мурино)» 12 этаж из 15
# ЖК «Эланд» 4 этаж из 18
# ЖК «Охтинская дуга» 10 этаж из 16
# Квартал «Солнечный» 16 этаж из 16
# ЖК «Охтинская дуга» 8 этаж из 16
# ЖК «Виктория (Мурино)» 7 этаж из 24
# ЖК «Виктория (Мурино)» 7 этаж из 20
# ЖК «Виктория (Мурино)» 11 этаж из 18
# ЖК «Мой город» 4 этаж из 24
# ЖК «Мой город» 14 этаж из 15
# ЖК «Охтинская дуга» 13 этаж из 17
# ЖК «Мой город» 16 этаж из 24

# %%
apartm_list=[]
for page in range(int(page_numb/4),int(page_numb/2)):
    soup=BeautifulSoup(requests.get(url_to_pages+str(page)).content,"html.parser")
    data=soup.find_all("ol",{"OffersSerp__list"})[0].find_all('li',{'OffersSerpItem'})
    print(page) # to track if there would be an error
    for item in data:
        apartm_dict={}
        link=site+item.find('a',{'OffersSerpItem__link'}, href=True)['href']
        new_soup=BeautifulSoup(requests.get(link).content,"html.parser").find_all('div',{'Offer'})[0]
        build=item.find_all('div',{'OffersSerpItem__building'})[0].text.split(', ')
        print(build) # to track if there would be an error
        
        apartm_dict['title']=item.find('h3',{'OffersSerpItem__title'}).text     
        apartm_dict['zhk']=build[0]
        try:
            apartm_dict['layer']=build[1]
        except:
            if 'этаж' in build[0]:
                apartm_dict['layer']=build[0]
                apartm_dict['zhk']=None
            else:
                apartm_dict['layer']=None
        apartm_dict['address']=item.find('div',{'OffersSerpItem__address'}).text
        try:
            fees=new_soup.find('span',{'OfferDealDescription__info-item'}).text
            if "комисси" in fees: 
                apartm_dict['fees']=fees
            else:
                apartm_dict['fees']=None  
        except:
            apartm_dict['fees']=None
        apartm_dict['location']=item.find('span',{'MetroWithTime__body'}).text[10:-5]
        apartm_dict['price']=item.find('span',{'price'}).text
        try:
            apartm_dict['desc']=item.find('p',{'OffersSerpItem__description'}).text
        except:    
            apartm_dict['desc']=None
        try:
            apartm_dict['full_desc']=new_soup.find('p',{'OfferTextDescription__text'}).text
        except:    
            apartm_dict['full_desc']=None
        try:
            apartm_dict['date']=new_soup.find('div',{'OfferPublishedDate'}).text
        except:
            apartm_dict['date']=item.find('div',{'OffersSerpItem__publish-date'}).text
        try:
            apartm_dict['update_date']=apartm_dict['date'].split('(')[1][10:-1]
        except:
            apartm_dict['update_date']=apartm_dict['date']
        apartm_dict['link']=link
        apartm_list.append(apartm_dict)

df=pd.DataFrame(apartm_list)
df.to_excel("second.xlsx")
result=pd.concat([pd.read_excel("rent_"+str(dt.now())[:11]+".xlsx"), df]).reset_index(drop=True)
result.to_excel("rent_"+str(dt.now())[:11]+".xlsx")
# Out:
# 3
# ЖК «Мой город» 11 этаж из 16
# ЖК «Мечта» 19 этаж из 23
# ЖК «Эланд» 19 этаж из 24
# ЖК «Эланд» 17 этаж из 22
# ЖК «Три кита» 5 этаж из 16
# ЖК «Три кита» 5 этаж из 12
# ЖК «Три кита» 3 этаж из 12
# ЖК «Мой город» 12 этаж из 24
# ЖК «Виктория (Мурино)» 10 этаж из 25
# ЖК «Охтинская дуга» 2 этаж из 16
# ЖК «Мой город» 7 этаж из 19
# ЖК «Мой город» 7 этаж из 15
# Квартал «Солнечный» 2 этаж из 20
# Квартал «Солнечный» 8 этаж из 16
# ЖК «Охтинская дуга» 10 этаж из 16
# Квартал «Солнечный» 14 этаж из 17
# ЖК «Виктория (Мурино)» 13 этаж из 13
# ЖК «Мечта» 9 этаж из 23
# ЖК «Виктория (Мурино)» 5 этаж из 24
# ЖК «Мой город» 21 этаж из 21
# 4
# ЖК «Мой город» 10 этаж из 22
# ЖК «Виктория (Мурино)» 15 этаж из 24
# ЖК «Три кита» 9 этаж из 12
# Квартал «Солнечный» 4 этаж из 16
# ЖК «Виктория (Мурино)» 13 этаж из 26
# ЖК «Мой город» 4 этаж из 22
# ЖК «Виктория (Мурино)» 3 этаж из 20
# ЖК «Мой город» 16 этаж из 25
# ЖК «Виктория (Мурино)» 19 этаж из 24
# ЖК «Виктория (Мурино)» 19 этаж из 24
# ЖК «Три кита» 12 этаж из 12
# Квартал «Солнечный» 6 этаж из 16
# Квартал «Солнечный» 6 этаж из 16
# ЖК «Виктория (Мурино)» 8 этаж из 12
# Квартал «Солнечный» 12 этаж из 16
# ЖК «Мой город» 20 этаж из 24
# ЖК «Мой город» 20 этаж из 24
# ЖК «Эланд» 20 этаж из 25
# ЖК «Мой город» 14 этаж из 22
# ЖК «Мой город» 11 этаж из 18
# 5
# ЖК «Виктория (Мурино)» 3 этаж из 18
# ЖК «Мечта» 1 этаж из 22
# ЖК «Виктория (Мурино)» 14 этаж из 22
# ЖК «Мой город» 5 этаж из 18
# ЖК «Виктория (Мурино)» 10 этаж из 25
# ЖК «Мой город» 19 этаж из 23
# ЖК «Виктория (Мурино)» 14 этаж из 19
# ЖК «Виктория (Мурино)» 14 этаж из 16
# ЖК «Мой город» 11 этаж из 25
# ЖК «Виктория (Мурино)» 16 этаж из 24
# ЖК «Виктория (Мурино)» 14 этаж из 22
# ЖК «Эланд» 23 этаж из 25
# ЖК «Мечта» 4 этаж из 20
# ЖК «Эланд» 17 этаж из 25
# ЖК «Три кита» 5 этаж из 18
# ЖК «Виктория (Мурино)» 4 этаж из 16
# ЖК «Мой город» 18 этаж из 25
# Квартал «Солнечный» 2 этаж из 16
# Квартал «Солнечный» 2 этаж из 20
# ЖК «Мечта» 1 этаж из 23
# 6
# ЖК «Мой город» 17 этаж из 24
# ЖК «Мечта» 12 этаж из 25
# ЖК «Мой город» 2 этаж из 20
# ЖК «Мой город» 6 этаж из 24
# ЖК «Мой город» 14 этаж из 21
# ЖК «Мой город» 9 этаж из 18
# ЖК «Эланд» 21 этаж из 24
# ЖК «Виктория (Мурино)» 20 этаж из 24
# ЖК «Мечта» 5 этаж из 20
# ЖК «Виктория (Мурино)» 3 этаж из 16
# ЖК «Виктория (Мурино)» 5 этаж из 16
# ЖК «Мой город» 9 этаж из 24
# ЖК «Мечта» 14 этаж из 14
# ЖК «Виктория (Мурино)» 22 этаж из 25
# ЖК «Мой город» 10 этаж из 16
# ЖК «Мой город» 14 этаж из 16
# ЖК «Эланд» 2 этаж из 23
# ЖК «Виктория (Мурино)» 24 этаж из 24
# ЖК «Виктория (Мурино)» 10 этаж из 18
# ЖК «Охтинская дуга» 12 этаж из 18

# %%
apartm_list=[]
for page in range(int(page_numb/2),int(page_numb*3/4)):
    soup=BeautifulSoup(requests.get(url_to_pages+str(page)).content,"html.parser")
    data=soup.find_all("ol",{"OffersSerp__list"})[0].find_all('li',{'OffersSerpItem'})
    print(page) # to track if there would be an error
    for item in data:
        apartm_dict={}
        link=site+item.find('a',{'OffersSerpItem__link'}, href=True)['href']
        new_soup=BeautifulSoup(requests.get(link).content,"html.parser").find_all('div',{'Offer'})[0]
        build=item.find_all('div',{'OffersSerpItem__building'})[0].text.split(', ')
        print(build) # to track if there would be an error
        
        apartm_dict['title']=item.find('h3',{'OffersSerpItem__title'}).text     
        apartm_dict['zhk']=build[0]
        try:
            apartm_dict['layer']=build[1]
        except:
            if 'этаж' in build[0]:
                apartm_dict['layer']=build[0]
                apartm_dict['zhk']=None
            else:
                apartm_dict['layer']=None
        apartm_dict['address']=item.find('div',{'OffersSerpItem__address'}).text
        try:
            fees=new_soup.find('span',{'OfferDealDescription__info-item'}).text
            if "комисси" in fees: 
                apartm_dict['fees']=fees
            else:
                apartm_dict['fees']=None  
        except:
            apartm_dict['fees']=None
        apartm_dict['location']=item.find('span',{'MetroWithTime__body'}).text[10:-5]
        apartm_dict['price']=item.find('span',{'price'}).text
        try:
            apartm_dict['desc']=item.find('p',{'OffersSerpItem__description'}).text
        except:    
            apartm_dict['desc']=None
        try:
            apartm_dict['full_desc']=new_soup.find('p',{'OfferTextDescription__text'}).text
        except:    
            apartm_dict['full_desc']=None
        try:
            apartm_dict['date']=new_soup.find('div',{'OfferPublishedDate'}).text
        except:
            apartm_dict['date']=item.find('div',{'OffersSerpItem__publish-date'}).text
        try:
            apartm_dict['update_date']=apartm_dict['date'].split('(')[1][10:-1]
        except:
            apartm_dict['update_date']=apartm_dict['date']
        apartm_dict['link']=link
        apartm_list.append(apartm_dict)

df=pd.DataFrame(apartm_list)
df.to_excel("third.xlsx")
result=pd.concat([pd.read_excel("rent_"+str(dt.now())[:11]+".xlsx"), df]).reset_index(drop=True)
result.to_excel("rent_"+str(dt.now())[:11]+".xlsx")
# Out:
# 7
# ЖК «Охтинская дуга» 12 этаж из 18
# ЖК «Три кита» 3 этаж из 12
# ЖК «Три кита» 3 этаж из 12
# ЖК «Три кита» 3 этаж из 12
# ЖК «Мой город» 19 этаж из 25
# Квартал «Солнечный» 10 этаж из 17
# ЖК «Мой город» 9 этаж из 24
# Квартал «Солнечный» 3 этаж из 16
# ЖК «Мой город» 16 этаж из 22
# ЖК «Мечта» 5 этаж из 13
# ЖК «Виктория (Мурино)» 4 этаж из 24
# ЖК «Виктория (Мурино)» 4 этаж из 20
# ЖК «Три кита» 4 этаж из 12
# Квартал «Солнечный» 16 этаж из 16
# ЖК «Эланд» 22 этаж из 25
# ЖК «Девятый вал» 20 этаж из 25
# ЖК «Охтинская дуга» 15 этаж из 16
# ЖК «Виктория (Мурино)» 12 этаж из 24
# ЖК «Мечта» 22 этаж из 22
# ЖК «Мой город» 11 этаж из 16
# 8
# ЖК «Мой город» 16 этаж из 24
# ЖК «Виктория (Мурино)» 2 этаж из 19
# ЖК «Виктория (Мурино)» 13 этаж из 19
# ЖК «Мой город» 3 этаж из 15
# ЖК «Мечта» 22 этаж из 22
# ЖК «Мечта» 14 этаж из 15
# ЖК «Эланд» 25 этаж из 25
# Квартал «YouПитер» 9 этаж из 21
# Квартал «YouПитер» 11 этаж из 20
# ЖК «Мой город» 16 этаж из 24
# ЖК «Девятый вал» 16 этаж из 25
# ЖК «Охтинская дуга» 5 этаж из 24
# Квартал «YouПитер» 11 этаж из 16
# ЖК «Мой город» 11 этаж из 24
# Квартал «YouПитер» 11 этаж из 16
# ЖК «Девятый вал» 18 этаж из 21
# ЖК «Ласточка» 2 этаж из 15
# ЖК «Ласточка» 4 этаж из 16
# Квартал «YouПитер» 14 этаж из 21
# ЖК «Мой город» 6 этаж из 24
# 9
# ЖК «Мой город» 6 этаж из 24
# ЖК «Ласточка» 6 этаж из 13
# ЖК «Мой город» 6 этаж из 22
# ЖК «GreenЛандия» 13 этаж из 22
# ЖК «Охтинская дуга» 14 этаж из 24
# ЖК «Ласточка» 15 этаж из 15
# ЖК «Мой город» 11 этаж из 24
# ЖК «GreenЛандия» 8 этаж из 22
# Квартал «Солнечный» 6 этаж из 17
# ЖК «Мой город» 21 этаж из 22
# ЖК «Ласточка» 7 этаж из 15
# ЖК «Ласточка» 7 этаж из 15
# ЖК «Охтинская дуга» 6 этаж из 22
# ЖК «Мой город» 18 этаж из 24
# ЖК «Мой город» 11 этаж из 24
# ЖК «Мой город» 11 этаж из 24
# ЖК «GreenЛандия» 6 этаж из 18
# ЖК «Охтинская дуга» 13 этаж из 24
# ЖК «Охтинская дуга» 17 этаж из 23
# ЖК «Мой город» 6 этаж из 24

# %%
apartm_list=[]
for page in range(int(page_numb*3/4),page_numb+1):
    soup=BeautifulSoup(requests.get(url_to_pages+str(page)).content,"html.parser")
    data=soup.find_all("ol",{"OffersSerp__list"})[0].find_all('li',{'OffersSerpItem'})
    print(page) # to track if there would be an error
    for item in data:
        apartm_dict={}
        link=site+item.find('a',{'OffersSerpItem__link'}, href=True)['href']
        new_soup=BeautifulSoup(requests.get(link).content,"html.parser").find_all('div',{'Offer'})[0]
        build=item.find_all('div',{'OffersSerpItem__building'})[0].text.split(', ')
        print(build) # to track if there would be an error
        
        apartm_dict['title']=item.find('h3',{'OffersSerpItem__title'}).text     
        apartm_dict['zhk']=build[0]
        try:
            apartm_dict['layer']=build[1]
        except:
            if 'этаж' in build[0]:
                apartm_dict['layer']=build[0]
                apartm_dict['zhk']=None
            else:
                apartm_dict['layer']=None
        apartm_dict['address']=item.find('div',{'OffersSerpItem__address'}).text
        try:
            fees=new_soup.find('span',{'OfferDealDescription__info-item'}).text
            if "комисси" in fees: 
                apartm_dict['fees']=fees
            else:
                apartm_dict['fees']=None  
        except:
            apartm_dict['fees']=None
        apartm_dict['location']=item.find('span',{'MetroWithTime__body'}).text[10:-5]
        apartm_dict['price']=item.find('span',{'price'}).text
        try:
            apartm_dict['desc']=item.find('p',{'OffersSerpItem__description'}).text
        except:    
            apartm_dict['desc']=None
        try:
            apartm_dict['full_desc']=new_soup.find('p',{'OfferTextDescription__text'}).text
        except:    
            apartm_dict['full_desc']=None
        try:
            apartm_dict['date']=new_soup.find('div',{'OfferPublishedDate'}).text
        except:
            apartm_dict['date']=item.find('div',{'OffersSerpItem__publish-date'}).text
        try:
            apartm_dict['update_date']=apartm_dict['date'].split('(')[1][10:-1]
        except:
            apartm_dict['update_date']=apartm_dict['date']
        apartm_dict['link']=link
        apartm_list.append(apartm_dict)

df=pd.DataFrame(apartm_list)
df.to_excel("fourth.xlsx")
result=pd.concat([pd.read_excel("rent_"+str(dt.now())[:11]+".xlsx"), df]).reset_index(drop=True)
result.to_excel("rent_"+str(dt.now())[:11]+".xlsx")
result.drop(['Unnamed: 0','Unnamed: 0.1.1','Unnamed: 0.1.1.1','level_0','index']], axis=1, inplace=True)
result.to_excel("rent_"+str(dt.now())[:11]+".xlsx")
# Out:
# 11
# ['ЖК «Ласточка»', '7\xa0этаж\xa0из\xa015']
# ['ЖК «Ласточка»', '7\xa0этаж\xa0из\xa015']
# ['ЖК «Охтинская дуга»', '6\xa0этаж\xa0из\xa022']
# ['ЖК «Мой город»', '18\xa0этаж\xa0из\xa024']
# ['ЖК «Мой город»', '11\xa0этаж\xa0из\xa024']
# ['ЖК «Мой город»', '11\xa0этаж\xa0из\xa024']
# ['ЖК «GreenЛандия»', '6\xa0этаж\xa0из\xa018']
# ['ЖК «Охтинская дуга»', '13\xa0этаж\xa0из\xa024']
# ['ЖК «Охтинская дуга»', '13\xa0этаж\xa0из\xa024']
# ['ЖК «Мой город»', '6\xa0этаж\xa0из\xa024']
# ['ЖК «GreenЛандия»', '14\xa0этаж\xa0из\xa022']
# ['Квартал «Солнечный»', '3\xa0этаж\xa0из\xa016']
# ['ЖК «Три кита»', '3\xa0этаж\xa0из\xa020']
# ['ЖК «Ласточка»', '6\xa0этаж\xa0из\xa019']
# ['ЖК «Ласточка»', '12\xa0этаж\xa0из\xa015']
# ['ЖК «Девятый вал»', '22\xa0этаж\xa0из\xa025']
# ['ЖК «GreenЛандия»', '16\xa0этаж\xa0из\xa023']
# ['ЖК «Охтинская дуга»', '17\xa0этаж\xa0из\xa024']
# ['ЖК «GreenЛандия»', '7\xa0этаж\xa0из\xa025']
# ['Квартал «YouПитер»', '8\xa0этаж\xa0из\xa018']
# 12
# ['ЖК «Ласточка»', '11\xa0этаж\xa0из\xa015']
# ['ЖК «Ласточка»', '4\xa0этаж\xa0из\xa024']
# ['ЖК «Ласточка»', '6\xa0этаж\xa0из\xa015']
# ['ЖК «Мой город»', '15\xa0этаж\xa0из\xa024']
# ['ЖК «Десяткино»', '8\xa0этаж\xa0из\xa019']
# ['ЖК «Ласточка»', '6\xa0этаж\xa0из\xa015']
# ['ЖК «Мой город»', '2\xa0этаж\xa0из\xa016']
# ['ЖК «Мой город»', '10\xa0этаж\xa0из\xa024']
# ['ЖК «Охтинская дуга»', '5\xa0этаж\xa0из\xa024']
# ['ЖК «Ласточка»', '2\xa0этаж\xa0из\xa09']
# ['ЖК «Мой город»', '18\xa0этаж\xa0из\xa024']
# ['ЖК «Охтинская дуга»', '3\xa0этаж\xa0из\xa024']
# ['ЖК «Охтинская дуга»', '7\xa0этаж\xa0из\xa024']
# ['ЖК «Сокол»', '5\xa0этаж\xa0из\xa016']
# ['ЖК «Ласточка»', '2\xa0этаж\xa0из\xa016']
# ['ЖК «Ласточка»', '2\xa0этаж\xa0из\xa015']
# ['ЖК «Мой город»', '24\xa0этаж\xa0из\xa024']
# ['ЖК «Ласточка»', '4\xa0этаж\xa0из\xa016']
# ['ЖК «Охтинская дуга»', '4\xa0этаж\xa0из\xa021']
# ['ЖК «Охтинская дуга»', '4\xa0этаж\xa0из\xa021']
# 13
# ['ЖК «Ласточка»', '1\xa0этаж\xa0из\xa010']
# ['ЖК «Охтинская дуга»', '8\xa0этаж\xa0из\xa024']
# ['ЖК «Девятый вал»', '3\xa0этаж\xa0из\xa025']
# ['Квартал «Солнечный»', '15\xa0этаж\xa0из\xa017']
# ['ЖК «Мой город»', '20\xa0этаж\xa0из\xa022']
# ['ЖК «Ласточка»', '14\xa0этаж\xa0из\xa016']
# ['ЖК «Охтинская дуга»', '10\xa0этаж\xa0из\xa016']
# ['ЖК «GreenЛандия»', '8\xa0этаж\xa0из\xa022']
# ['ЖК «Охтинская дуга»', '16\xa0этаж\xa0из\xa022']
# ['2\xa0этаж\xa0из\xa03']
# ['ЖК «Мой город»', '12\xa0этаж\xa0из\xa024']
# ['ЖК «Мой город»', '9\xa0этаж\xa0из\xa025']
# ['Квартал «Солнечный»', '3\xa0этаж\xa0из\xa016']
# ['ЖК «Охтинская дуга»', '17\xa0этаж\xa0из\xa023']
# ['ЖК «Ласточка»', '15\xa0этаж\xa0из\xa015']
# ['ЖК «GreenЛандия»', '4\xa0этаж\xa0из\xa022']
# ['ЖК «Ласточка»', '10\xa0этаж\xa0из\xa015']
# ['ЖК «Мой город»', '4\xa0этаж\xa0из\xa025']
# ['ЖК «Три кита»', '6\xa0этаж\xa0из\xa012']
# ['ЖК «Ласточка»', '11\xa0этаж\xa0из\xa015']
# 14
# ['ЖК «Охтинская дуга»', '13\xa0этаж\xa0из\xa025']
# ['2\xa0этаж\xa0из\xa04']
# ['ЖК «Охтинская дуга»', '12\xa0этаж\xa0из\xa024']
# ['ЖК «GreenЛандия»', '3\xa0этаж\xa0из\xa022']
# ['ЖК «Ласточка»', '8\xa0этаж\xa0из\xa015']
# ['Квартал «YouПитер»', '6\xa0этаж\xa0из\xa022']
# ['ЖК «Мой город»', '24\xa0этаж\xa0из\xa025']
# ['ЖК «Ласточка»', '3\xa0этаж\xa0из\xa015']
# ['ЖК «Охтинская дуга»', '21\xa0этаж\xa0из\xa024']
# ['ЖК «Мой город»', '12\xa0этаж\xa0из\xa024']
# ['Квартал «YouПитер»', '4\xa0этаж\xa0из\xa021']
# ['Квартал «Солнечный»', '4\xa0этаж\xa0из\xa016']
# ['ЖК «Девятый вал»', '4\xa0этаж\xa0из\xa025']
# ['ЖК «GreenЛандия»', '13\xa0этаж\xa0из\xa022']
# ['ЖК «GreenЛандия»', '16\xa0этаж\xa0из\xa021']
# ['Квартал «YouПитер»', '9\xa0этаж\xa0из\xa021']
# ['ЖК «Охтинская дуга»', '12\xa0этаж\xa0из\xa024']
# ['ЖК «Мой город»', '21\xa0этаж\xa0из\xa024']
# ['ЖК «Мой город»', '5\xa0этаж\xa0из\xa024']
# ['ЖК «Ласточка»', '15\xa0этаж\xa0из\xa015']
# 15
# ['ЖК «Ласточка»', '9\xa0этаж\xa0из\xa015']
# ['ЖК «Ласточка»', '9\xa0этаж\xa0из\xa015']
# ['Квартал «Солнечный»', '10\xa0этаж\xa0из\xa016']
# ['ЖК «Ласточка»', '13\xa0этаж\xa0из\xa015']
# ['ЖК «Мой город»', '11\xa0этаж\xa0из\xa024']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-14da3bb09c6a> in <module>
#      53 df=pd.DataFrame(apartm_list)
#      54 df.to_excel("fourth.xlsx")
# ---> 55 result=pd.concat([pd.read_excel("rent.xlsx"), df]).reset_index()
#      56 result.to_excel("rent.xlsx")
#
# c:\users\125\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# c:\users\125\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# c:\users\125\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
result=pd.concat([pd.read_excel("rent_"+str(dt.now())[:11]+".xlsx"), df]).reset_index(drop=True)
def metro(loc): return 'Close' if loc<=11 else 'Far'
result['metro']=[metro(loc) for loc in result.location]
result.drop(['Unnamed: 0','Unnamed: 0.1.1','Unnamed: 0.1.1.1','level_0','index'], axis=1, inplace=True)
result.drop_duplicates(keep=first, inplace=True)
result.to_excel("rent_"+str(dt.now())[:11]+".xlsx")

# %%
result=pd.concat([pd.read_excel("first.xlsx"), pd.read_excel("second.xlsx"), pd.read_excel("third.xlsx"), pd.read_excel("fourth.xlsx")]).reset_index(drop=True)
result.drop(['Unnamed: 0'], axis=1, inplace=True)
def metro(loc): return 'Close' if loc<=11 else 'Far'
result['metro']=[metro(loc) for loc in result.location]
result.drop_duplicates(keep=first, inplace=True)
result.to_excel("rent_v2_"+str(dt.now())[:11]+".xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-4dce41559640> in <module>
#       2 result.drop(['Unnamed: 0'], axis=1, inplace=True)
#       3 def metro(loc): return 'Close' if int(loc)<=11 else 'Far'
# ----> 4 result['metro']=[metro(loc) for loc in result.location]
#       5 result.to_excel("rent_v2_"+str(dt.now())[:11]+".xlsx")
#
# <ipython-input-53-4dce41559640> in <listcomp>(.0)
#       2 result.drop(['Unnamed: 0'], axis=1, inplace=True)
#       3 def metro(loc): return 'Close' if int(loc)<=11 else 'Far'
# ----> 4 result['metro']=[metro(loc) for loc in result.location]
#       5 result.to_excel("rent_v2_"+str(dt.now())[:11]+".xlsx")
#
# <ipython-input-53-4dce41559640> in metro(loc)
#       1 result=pd.concat([pd.read_excel("first.xlsx"), pd.read_excel("second.xlsx"), pd.read_excel("third.xlsx"), pd.read_excel("fourth.xlsx")]).reset_index(drop=True)
#       2 result.drop(['Unnamed: 0'], axis=1, inplace=True)
# ----> 3 def metro(loc): return 'Close' if int(loc)<=11 else 'Far'
#       4 result['metro']=[metro(loc) for loc in result.location]
#       5 result.to_excel("rent_v2_"+str(dt.now())[:11]+".xlsx")
#
# ValueError: invalid literal for int() with base 10: '10 мин.'
